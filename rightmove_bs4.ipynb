# %% [markdown]
# rightmove web scrapper

# %%
# import all neccessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
rm_salesurl = "https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E87490&index={index}&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="
rm_renturl = "https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E87490&index={index}&propertyTypes=&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords="

# %%
def connect_page(url, start, stop, increment):
    try:
        pages = []  # List to store all the pages

        for i in range(start, stop, increment):
            # Format the URL with the updated index value
            page_html = url.format(index=i)

            response = requests.get(page_html)
            if response.status_code == 200:
                content = BeautifulSoup(response.content, 'html.parser')
                page = BeautifulSoup(content.prettify(), 'html.parser')
                pages.append(page)  # Add the page to the list
                

            else:
                print("Error:", response.status_code)
                # Handle the error condition if needed

        return pages  # Return the list of pages

    except requests.ConnectionError as e:
        print("Connection Error:", str(e))

        

def get_data(pages:'html page', transaction_type:str, source:str):

    addresses = []
    bedrooms = []
    bathrooms = []
    descriptions = []
    property_types = []
    prices = []
    locations = []
    agents = []
    listing_urls = []
    date_type = []
    dates = []

    for page in pages:
        
        address_elements = page.find_all('address', class_='propertyCard-address')
        for item in address_elements:
            address = item.get_text(strip=True) if item else ""
            addresses.append(address)
        
        bedroom_elements = page.find_all('span', {'class': 'no-svg-bed-icon bed-icon seperator'})
        bedroom = " "
        for item in bedroom_elements:
            bedroom = item['title'] if item else ""
            bedrooms.append(bedroom)

        bathroom_elements = page.find_all('span', class_='no-svg-bathroom-icon bathroom-icon seperator')
        bathroom=" "
        for item in bathroom_elements:
            bathroom = item.get_text(strip=True) if item else ""
            bathrooms.append(bathroom)


        description_elements = page.find_all('span', itemprop="description")
        for item in description_elements:
            description = item.get_text(strip=True) if item else ""
            descriptions.append(description)

        property_type_elements = page.find_all(class_="propertyCard-title")
        for item in property_type_elements:
            property_type_text = item.get_text(strip=True) if item else ""
            property_type = property_type_text.split(",")[0].strip() if property_type_text else ""
            property_types.append( property_type)

        price_elements = page.find_all('div', class_="propertyCard-priceValue")
        for item in price_elements:
            price = item.get_text(strip=True) if item else ""
            prices.append(price)

        location_elements = page.find_all('address', class_="propertyCard-address")
        for item in location_elements:
            address = item.get_text(strip=True) if item else ""
            location = address.split(",")[-1].strip() if address else ""
            locations.append(location)

        
        agent_elements = page.find_all('a', {'class': 'propertyCard-branchLogo-link'})
        for item in agent_elements:
            agent = item['title'] if item else ""
            agents.append(agent)

        listing_url_elements = page.find_all('a', {'class': 'propertyCard-branchLogo-link'})
        for item in listing_url_elements:
            listing_url = 'https://www.rightmove.co.uk' + item['href'] if item else ""
            listing_urls.append(listing_url)

        date_added_elements = page.find_all('span', class_="propertyCard-contactsAddedOrReduced")
        for item in date_added_elements:
            datetype = item.get_text(strip=True).split(" on ")[0].strip() if item else ""
            date_added = item.get_text(strip=True).split(" on ")[-1].strip() if item else ""
            dates.append(date_added)
            date_type.append(datetype)

        listing_source = source
        transaction = transaction_type
  
        data = pd.DataFrame()
        data['address']= addresses
        data['address']= addresses 
        # data['bedroom']=bedrooms 
        # data['bathroom']=bathrooms 
        data['description']=descriptions 
        data['property_type']=property_types 
        data['price']=prices 
        data['location']=locations 
        # data['agent']=agents
        data['transaction_type'] = transaction
        data['listing_source'] = listing_source
        # data['listing_url']=listing_urls 
        data['date_type']=date_type 
        data['date']=dates 


    return data

# %%
# Set the range of indexes you want to loop through
start_index = 0
stop_index = 24
increment = 24

# Call the function with the URL and index range
page = connect_page(rm_salesurl, start_index, stop_index, increment)
df = get_data(page,'sales', 'rightmove') 
len(df)
# Out:
# 25

# %%
df
# Out:
#                                               address  \
# 0                                   The Driftway, Bow
# 1                        One Hyde Park, Knightsbridge
# 2                        Lygon Place, Belgravia, SW1W
# 3         Mayfair Freehold House, Park Lane Area, W1K
# 4                             Pitt Street, London, W8
# 5                         Pitt Street, Kensington, W8
# 6   Belgravia Gate, Grosvenor Crescent, Belgravia,...
# 7                           Brick Street, Mayfair W1J
# 8                           South Street, Mayfair W1K
# 9                           Royal Westminster, London
# 10                 Brick Street, Mayfair, London, W1J
# 11                 Brick Street, Mayfair, London, W1J
# 12                   Piccadilly, Mayfair, London, W1J
# 13                               South Street, London
# 14                            Merton Lane, London, N6
# 15                                  Mayfair Penthouse
# 16              Princes Gate, Kensington, London, SW7
# 17                   Princes Gate, Knightsbridge, SW7
# 18                       One Hyde Park, Knightsbridge
# 19         Hanover Terrace, Regents Park, London, NW1
# 20                      Chapel Street, Belgravia SW1X
# 21                         Curzon Street, London, W1J
# 22                                        Westminster
# 23                Marylebone High Street, London, W1U
# 24                         Culross House, London, W1K
#
#                                           description  \
# 0   Price Guide £425,000 - £450,000 Positioned wit...
# 1   An exceptional exclusive five bedroom apartmen...
# 2   Ref. LOB0798 - Set behind a gated Belgravia dr...
# 3   This stunning 12 bedroom (including 3 staff be...
# 4   A rare opportunity to own this unique, contemp...
# 5   Ref. LOB0625 - This striking and unique house ...
# 6   Belgravia Gate benefits from a truly world-cla...
# 7   A truly exeptional low- built 7 bedroom mansio...
# 8   Considered to be the archetypical London mansi...
# 9   A very rare find this luxurious circa 11000 SQ...
# 10  A majestic and luxurious Grade II listed build...
# 11  Luxurious Grade II listed house with private g...
# 12  A rare opportunity to regenerate an impressive...
# 13  An elegant stone-dressed, red-brick, five-stor...
# 14  United Kingdom Sotheby’s International Realty ...
# 15  Luxury Penthouse in the heart of Mayfair. Over...
# 16  An elegant fronted house providing over 9,000 ...
# 17  7 Bedroom house in one of Knightsbridge's most...
# 18  The Cloister are pleased to present this stunn...
# 19  United Kingdom Sotheby’s International Realty ...
# 20  A magnificent, exceptionally well presented si...
# 21  Incredible investment opportunity to acquire f...
# 22                                         9 Millbank
# 23  The most eagerly awaited residential developme...
# 24  Bespoke Mayfair home in enviable location insp...
#
#                               property_type        price           location  \
# 0              1 bedroom apartment for sale     £425,000                Bow
# 1              5 bedroom apartment for sale  £60,000,000      Knightsbridge
# 2                  7 bedroom house for sale  £45,000,000               SW1W
# 3                 12 bedroom house for sale  £45,000,000                W1K
# 4         7 bedroom detached house for sale  £44,000,000                 W8
# 5                  6 bedroom house for sale  £44,000,000                 W8
# 6               6 bedroom property for sale  £43,700,000               SW1X
# 7                  7 bedroom house for sale  £35,000,000        Mayfair W1J
# 8                  6 bedroom house for sale  £35,000,000        Mayfair W1K
# 9         7 bedroom detached house for sale  £35,000,000             London
# 10        7 bedroom terraced house for sale  £35,000,000                W1J
# 11        7 bedroom detached house for sale  £35,000,000                W1J
# 12                  Terraced house for sale  £35,000,000                W1J
# 13        5 bedroom terraced house for sale  £35,000,000             London
# 14        6 bedroom detached house for sale  £32,000,000                 N6
# 15             5 bedroom penthouse for sale  £30,000,000  Mayfair Penthouse
# 16                 7 bedroom house for sale  £30,000,000                SW7
# 17                 7 bedroom house for sale  £30,000,000                SW7
# 18             3 bedroom apartment for sale  £30,000,000      Knightsbridge
# 19  6 bedroom end of terrace house for sale  £29,000,000                NW1
# 20            6 bedroom town house for sale  £28,000,000     Belgravia SW1X
# 21  11 bedroom block of apartments for sale  £27,800,000                W1J
# 22             4 bedroom penthouse for sale  £27,500,000        Westminster
# 23             3 bedroom penthouse for sale  £27,000,000                W1U
# 24        6 bedroom terraced house for sale  £26,950,000                W1K
#
#    transaction_type listing_source date_type        date
# 0             sales      rightmove   Reduced  12/05/2023
# 1             sales      rightmove     Added  22/12/2022
# 2             sales      rightmove     Added  21/11/2022
# 3             sales      rightmove     Added  31/12/2022
# 4             sales      rightmove     Added  20/02/2023
# 5             sales      rightmove     Added  21/02/2023
# 6             sales      rightmove     Added  02/05/2023
# 7             sales      rightmove     Added  22/02/2023
# 8             sales      rightmove     Added  09/03/2023
# 9             sales      rightmove     Added  04/05/2023
# 10            sales      rightmove     Added  22/02/2023
# 11            sales      rightmove     Added  24/09/2022
# 12            sales      rightmove     Added  25/04/2023
# 13            sales      rightmove     Added  18/10/2022
# 14            sales      rightmove   Reduced  21/02/2023
# 15            sales      rightmove     Added  10/01/2023
# 16            sales      rightmove     Added  17/10/2022
# 17            sales      rightmove     Added  13/01/2023
# 18            sales      rightmove     Added  22/12/2022
# 19            sales      rightmove     Added  28/01/2022
# 20            sales      rightmove     Added  25/10/2019
# 21            sales      rightmove     Added  17/02/2023
# 22            sales      rightmove     Added  12/05/2023
# 23            sales      rightmove     Added  28/02/2023
# 24            sales      rightmove     Added  13/02/2023

# %%
def get_data(page, transaction_type, source):

    addresses = []
    bedrooms = []
    bathrooms = []
    descriptions = []
    property_types = []
    prices = []
    locations = []
    agents = []
    listing_urls = []
    dates = []


    address_elements = page.find_all('address', class_='propertyCard-address')
    for item in address_elements:
        address = item.get_text(strip=True) if item else ""
        addresses.append(address)

    bedroom_elements = page.find_all('span', {'class': 'no-svg-bed-icon bed-icon seperator'})
    bedroom = " "
    for item in bedroom_elements:
        bedroom = item['title'] if item else ""
        bedrooms.append(bedroom)

    bathroom_elements = page.find_all('span', class_='no-svg-bathroom-icon bathroom-icon seperator')
    bathroom=" "
    for item in bathroom_elements:
        bathroom = item.get_text(strip=True) if item else ""
        bathrooms.append(bathroom)

    description_elements = page.find_all('span', itemprop="description")
    for item in description_elements:
        description = item.get_text(strip=True) if item else ""
        descriptions.append(description)

    property_type_elements = page.find_all(class_="propertyCard-title")
    for item in property_type_elements:
        property_type_text = item.get_text(strip=True) if item else ""
        property_type = property_type_text.split(",")[0].strip() if property_type_text else ""
        property_types.append( property_type)

    price_elements = page.find_all('div', class_="propertyCard-priceValue")
    for item in price_elements:
        price = item.get_text(strip=True) if item else ""
        prices.append(price)

    location_elements = page.find_all('address', class_="propertyCard-address")
    for item in location_elements:
        address = item.get_text(strip=True) if item else ""
        location = address.split(",")[-1].strip() if address else ""
        locations.append(location)

    agent_elements = page.find_all('a', {'class': 'propertyCard-branchLogo-link'})
    for item in agent_elements:
        agent = item['title'] if item else ""
        agents.append(agent)

    # listing_source = str(source)
    # transaction = transactions.append(str(transaction_type))

    listing_url_elements = page.find_all('a', {'class': 'propertyCard-branchLogo-link'})
    for item in listing_url_elements:
        listing_url = 'https://www.rightmove.co.uk' + item['href'] if item else ""
        listing_urls.append(listing_url)

    date_added_elements = page.find_all('span', class_="propertyCard-contactsAddedOrReduced")
    for item in date_added_elements:
        date_added = item.get_text(strip=True) if item else ""
        dates.append(date_added)


    data = pd.DataFrame()
    # data['transaction'] = 
    data['address']= addresses
    data['address']=addresses 
    # data['bedroom']=bedrooms 
    # data['bathroom']=bathrooms 
    data['description']=descriptions 
    data['property_type']=property_types 
    data['price']=prices 
    data['location']=locations 
    # data['agent']=agents 
    # data['listing_url']=listing_urls 
    data['date_added']=dates 


    return data
